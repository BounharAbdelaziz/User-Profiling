# %%
import pandas as pd

# %%
import numpy as np

import nltk
# Stop words
from nltk.corpus import stopwords
# Tokenization
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
# POS-TAGS
from nltk import pos_tag

nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv('datas.csv', encoding='utf-8', error_bad_lines=False, delimiter =";")
# ISO-8859-1
# utf-8

# %%
df.head()
# Out:
#    id    sender   receiver date_envoie heure_envoie  \
# 0   1     Cordy      Kalle  02/11/2016     04:58:28
# 1   2   Pierson  Sebastien  11/26/2016     16:12:57
# 2   3  Corrinne     Bibbye  02/10/2018     10:50:33
# 3   4    Berton   Tiffanie  04/10/2018     07:49:48
# 4   5      Gael     Evered   2/27/2018     06:58:03
#
#                                              message  sentiment  liked  \
# 0                        What salary would you like?        NaN    NaN
# 1   I don't understand. I want to talk about movi...        NaN    NaN
# 2     Yay! I love moveis. What your favorite movies?        NaN    NaN
# 3   Whoopie!  How long has this been going on?   ...        NaN    NaN
# 4                        What is your favorite song?        NaN    NaN
#
#    disliked  keywords_interests
# 0       NaN                 NaN
# 1       NaN                 NaN
# 2       NaN                 NaN
# 3       NaN                 NaN
# 4       NaN                 NaN

# %% [markdown]
# # Tokenization

# %%
from nltk.tokenize import RegexpTokenizer

##### Applying Word tokenization

def tokenize(message):
    tokenizer = RegexpTokenizer(r'\w+')
    tokenized_word = tokenizer.tokenize(message)
    
    return tokenized_word

# %%
# exemple
pos_tag(['going','cried'])
# Out:
# [('going', 'VBG'), ('cried', 'VBD')]

# %% [markdown]
# ## Stop words

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')

stopwords_verbs = ['say', 'get', 'go', 'know', 'may', 'need', 'like', 'make', 'see', 'want', 'come', 'take', 'use', 'would', 'can']
stopwords_other = ['one', 'mr', 'bbc', 'image', 'getty', 'de', 'en', 'caption', 'also', 'copyright', 'something']

stopwords = stopwords.words("english") + stopwords_other + stopwords_verbs

# we wont use 'to' as a stopword because it will cause a problem with verbs like (to talk) 
# talk will be seen as a noun inspite of a verb
to_index = stopwords.index('to')
stopwords.pop(to_index)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 'to'

# %% [markdown]
# # POS-Tagging

# %%
##### Applying POS-TAGGING

def pos_tagging(tokenized_word) :
    POS_TOKENS = pos_tag(tokenized_word)
    return POS_TOKENS

# %% [markdown]
# ## Remove stop words from Tokenized sentence

# %%
#### Removing stop words from the tokenized word 

def remove_stopWords_msg(POS_TOKENS) :
    final_msg = []
    
    for token in POS_TOKENS :
        if token[0].lower() not in stopwords:
            final_msg.append(token[0])

    return final_msg

# %% [markdown]
# # First occurence of a noun

# %%
VERBS_TAGS = ['VB','VBD','VBG','VBP','VBN','VBZ']
NOUNS_TAGS = ['NN','NNP','NNS']

#NOUNS_TAGS = ['NN','NNP','NNPS','NNS']

def firstNounAfter(position , pos_tags) :
  for i in range (position , len(pos_tags)-1) :
    if (pos_tags[i][1] in NOUNS_TAGS):
      return pos_tags[i][0]

def firstNounBefore(position, pos_tags) :
  i = position
  while (i>=0) :
    if (pos_tags[i][1] in NOUNS_TAGS):
      return pos_tags[i][0]
    i = i-1

# %% [markdown]
# # Traitement

# %%
def traitement(words) :
    
    ############
        
    tokenized_word = []
    POS_TOKENS = []
    
    ############

    tokenized_word = tokenize(words)
    POS_TOKENS = pos_tagging(tokenized_word)

    tokenized_msg_without_stop_words = remove_stopWords_msg(POS_TOKENS)
    POS_TOKENS = pos_tagging(tokenized_msg_without_stop_words)
  

  
    return POS_TOKENS

# %%
def chunk_msg(msg):
    
    grammar = "Chunk: {<VB.?><NN.?>+}"       
    
    #grammar = "Chunk: {<VB.?>*<NN.?>+|<NN.?>+<VB.?>}"

    parser = nltk.RegexpParser(grammar)
    chunked = parser.parse(msg)


    NOUNS = []

    for subtree in chunked.subtrees(filter=lambda t: t.label() == 'Chunk'):
    
        grammar_sub = "chunked_sub: {<NN.?>+}"

        parser_sub = nltk.RegexpParser(grammar_sub)
        chunked_sub = parser_sub.parse(subtree)

        if chunked_sub :
            for c in chunked_sub.subtrees(filter=lambda t: t.label() == 'chunked_sub'):
                for i in range(0,len(c)):
                    NOUNS.append(c[i][0])     


    print("[INFO] : NOUNS = ",NOUNS)
    return NOUNS

# %% [markdown]
# # Exemple on one row

# %%
message = df['message'][8000]
print("[INFO] MESSAGE : ",message)

p = traitement(message)
print("[INFO] FUNCTION RETURN : ",p)
# Out:
# [INFO] MESSAGE :   You mentioned it I think.
# [INFO] FUNCTION RETURN :  [('mentioned', 'VBN'), ('think', 'NN')]

# %%
chunk_msg(p)
# Out:
# [INFO] : NOUNS =  ['think']
# ['think']

# %%
df.head()
# Out:
#    id    sender   receiver date_envoie heure_envoie  \
# 0   1     Cordy      Kalle  02/11/2016     04:58:28
# 1   2   Pierson  Sebastien  11/26/2016     16:12:57
# 2   3  Corrinne     Bibbye  02/10/2018     10:50:33
# 3   4    Berton   Tiffanie  04/10/2018     07:49:48
# 4   5      Gael     Evered   2/27/2018     06:58:03
#
#                                              message  sentiment  liked  \
# 0                        What salary would you like?        NaN    NaN
# 1   I don't understand. I want to talk about movi...        NaN    NaN
# 2     Yay! I love moveis. What your favorite movies?        NaN    NaN
# 3   Whoopie!  How long has this been going on?   ...        NaN    NaN
# 4                        What is your favorite song?        NaN    NaN
#
#    disliked  keywords_interests
# 0       NaN                 NaN
# 1       NaN                 NaN
# 2       NaN                 NaN
# 3       NaN                 NaN
# 4       NaN                 NaN

# %% [markdown]
# # All of the dataset traitement

# %%
# I had some issue with the built in json librairie so I searched for a similar librairie and used it.
# To install simplejson librairie : pip install simplejson==3.16.0
import simplejson as json

# %%
dataset_length = 9000
#dataset_length = 10109
for i in range(0, dataset_length) :
    total_dict = []
    total_dict.append(df.loc[i , 'sender'])
    print("----------------------------------------- ")

    m = df['message'][i]
    print("[INFO] MESSAGE = ",m)

    msg_lower_case = m.lower()

    t = traitement(msg_lower_case)
    print("[INFO] TRAITEMENT = ",t)


    nouns = chunk_msg(t)

    keys= ""

    df.loc[i , 'liked'] = ""
    
    # one keyword
    keyword = {}
    for noun in nouns :
        print("[INFO] index = ",i,"noun = ", noun)
        #data_frame['Keywords'][i] = data_frame['Keywords'][i] + "; "+noun

        df.loc[i , 'liked'] =  df.loc[i , 'liked']  + str(noun)+ "; "
     
        keyword["Keyword"] = noun        
        keyword["Count"] = 1
    
    if (keyword) :
        total_dict.append(keyword)
    print ("-[INFO]- total_dict : ",total_dict)
    print ("-[INFO]- json : ",json.dumps(total_dict))
    df.loc[i , 'keywords_interests'] =  json.dumps(total_dict)


        
        
###
        # we check if the keyword already exist
        #if(keyword["Keyword"]) :
        #if noun in keyword.values() :
            #keyword["Count"] = keyword["Count"] + 1
        #else :
###
# Out:
# -----------------------------------------
# [INFO] MESSAGE =   What salary would you like?
# [INFO] TRAITEMENT =  [('salary', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Cordy']
# -[INFO]- json :  ["Cordy"]
# -----------------------------------------
# [INFO] MESSAGE =   I don't understand. I want to talk about movies     .
# [INFO] TRAITEMENT =  [('understand', 'NN'), ('to', 'TO'), ('talk', 'VB'), ('movies', 'NNS')]
# [INFO] : NOUNS =  ['movies']
# [INFO] index =  1 noun =  movies
# -[INFO]- total_dict :  ['Pierson', {'Keyword': 'movies', 'Count': 1}]
# -[INFO]- json :  ["Pierson", {"Keyword": "movies", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Yay! I love moveis. What your favorite movies?
# [INFO] TRAITEMENT =  [('yay', 'RB'), ('love', 'VB'), ('moveis', 'NN'), ('favorite', 'JJ'), ('movies', 'NNS')]
# [INFO] : NOUNS =  ['moveis']
# [INFO] index =  2 noun =  moveis
# -[INFO]- total_dict :  ['Corrinne', {'Keyword': 'moveis', 'Count': 1}]
# -[INFO]- json :  ["Corrinne", {"Keyword": "moveis", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Whoopie!  How long has this been going on?         I don't have a favourite movies! My favourite colour is yellow.
# [INFO] TRAITEMENT =  [('whoopie', 'NN'), ('long', 'RB'), ('going', 'VBG'), ('favourite', 'JJ'), ('movies', 'NNS'), ('favourite', 'VBP'), ('colour', 'NNS'), ('yellow', 'VB')]
# [INFO] : NOUNS =  ['colour']
# [INFO] index =  3 noun =  colour
# -[INFO]- total_dict :  ['Berton', {'Keyword': 'colour', 'Count': 1}]
# -[INFO]- json :  ["Berton", {"Keyword": "colour", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   What is your favorite song?
# [INFO] TRAITEMENT =  [('favorite', 'NN'), ('song', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Gael']
# -[INFO]- json :  ["Gael"]
# -----------------------------------------
# [INFO] MESSAGE =   My favourite song is If I Only Had A Brain.
# [INFO] TRAITEMENT =  [('favourite', 'NN'), ('song', 'NN'), ('brain', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Gavan']
# -[INFO]- json :  ["Gavan"]
# -----------------------------------------
# [INFO] MESSAGE =   I'm disappointed. I really thought this program would be more convincing.
# [INFO] TRAITEMENT =  [('disappointed', 'VBN'), ('really', 'RB'), ('thought', 'JJ'), ('program', 'NN'), ('convincing', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Frazier']
# -[INFO]- json :  ["Frazier"]
# -----------------------------------------
# [INFO] MESSAGE =   I am sorry if I have disappointed you.     What gave you that idea?
# [INFO] TRAITEMENT =  [('sorry', 'NN'), ('disappointed', 'VBD'), ('gave', 'VBD'), ('idea', 'NN')]
# [INFO] : NOUNS =  ['idea']
# [INFO] index =  7 noun =  idea
# -[INFO]- total_dict :  ['Olga', {'Keyword': 'idea', 'Count': 1}]
# -[INFO]- json :  ["Olga", {"Keyword": "idea", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   I never did have that idea.
# [INFO] TRAITEMENT =  [('never', 'RB'), ('idea', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Kylie']
# -[INFO]- json :  ["Kylie"]
# -----------------------------------------
# [INFO] MESSAGE =   Because you can't afford it?
# [INFO] TRAITEMENT =  [('afford', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Tamas']
# -[INFO]- json :  ["Tamas"]
# -----------------------------------------
# [INFO] MESSAGE =   I can't afford what? You?
# [INFO] TRAITEMENT =  [('afford', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Kalil']
# -[INFO]- json :  ["Kalil"]
# -----------------------------------------
# [INFO] MESSAGE =   Is it very expensive?  I am just a humble chatbot.
# [INFO] TRAITEMENT =  [('expensive', 'JJ'), ('humble', 'JJ'), ('chatbot', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Cari']
# -[INFO]- json :  ["Cari"]
# -----------------------------------------
# [INFO] MESSAGE =   Are you?
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Bord']
# -[INFO]- json :  ["Bord"]
# -----------------------------------------
# [INFO] MESSAGE =   I can't be entirely sure.
# [INFO] TRAITEMENT =  [('entirely', 'RB'), ('sure', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Orv']
# -[INFO]- json :  ["Orv"]
# -----------------------------------------
# [INFO] MESSAGE =   Use my name!
# [INFO] TRAITEMENT =  [('name', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Arny']
# -[INFO]- json :  ["Arny"]
# -----------------------------------------
# [INFO] MESSAGE =   What is your name?
# [INFO] TRAITEMENT =  [('name', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lucita']
# -[INFO]- json :  ["Lucita"]
# -----------------------------------------
# [INFO] MESSAGE =   That's a horrible name...
# [INFO] TRAITEMENT =  [('horrible', 'JJ'), ('name', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Sarah']
# -[INFO]- json :  ["Sarah"]
# -----------------------------------------
# [INFO] MESSAGE =   What's so horrible about it?
# [INFO] TRAITEMENT =  [('horrible', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Kriste']
# -[INFO]- json :  ["Kriste"]
# -----------------------------------------
# [INFO] MESSAGE =   I thought you might know.   Please don't put words into my mouth.  That's enough about you! Let's talk about me for a change.
# [INFO] TRAITEMENT =  [('thought', 'NN'), ('might', 'MD'), ('please', 'VB'), ('put', 'VB'), ('words', 'NNS'), ('mouth', 'RB'), ('enough', 'RB'), ('let', 'JJ'), ('talk', 'VB'), ('change', 'VB')]
# [INFO] : NOUNS =  ['words']
# [INFO] index =  18 noun =  words
# -[INFO]- total_dict :  ['Olga', {'Keyword': 'words', 'Count': 1}]
# -[INFO]- json :  ["Olga", {"Keyword": "words", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   I don't want to change.
# [INFO] TRAITEMENT =  [('to', 'TO'), ('change', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Selle']
# -[INFO]- json :  ["Selle"]
# -----------------------------------------
# [INFO] MESSAGE =   Nobody can make you do something you don't want to.
# [INFO] TRAITEMENT =  [('nobody', 'NN'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Arin']
# -[INFO]- json :  ["Arin"]
# -----------------------------------------
# [INFO] MESSAGE =   But can you make me breakfast?
# [INFO] TRAITEMENT =  [('breakfast', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Jory']
# -[INFO]- json :  ["Jory"]
# -----------------------------------------
# [INFO] MESSAGE =   I can't make you do anything you don't want to.
# [INFO] TRAITEMENT =  [('anything', 'NN'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Stevie']
# -[INFO]- json :  ["Stevie"]
# -----------------------------------------
# [INFO] MESSAGE =   You cannot make me do anything, but you are certainly influencing the way I am phrasing my answers.
# [INFO] TRAITEMENT =  [('cannot', 'NN'), ('anything', 'NN'), ('certainly', 'RB'), ('influencing', 'VBG'), ('way', 'NN'), ('phrasing', 'VBG'), ('answers', 'NNS')]
# [INFO] : NOUNS =  ['way', 'answers']
# [INFO] index =  23 noun =  way
# [INFO] index =  23 noun =  answers
# -[INFO]- total_dict :  ['Ynez', {'Keyword': 'answers', 'Count': 1}]
# -[INFO]- json :  ["Ynez", {"Keyword": "answers", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Maybe I don't want to make you.
# [INFO] TRAITEMENT =  [('maybe', 'RB'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Glenn']
# -[INFO]- json :  ["Glenn"]
# -----------------------------------------
# [INFO] MESSAGE =   Oh, well. Bye, I'll find someone clever enough to continue the conversation with.
# [INFO] TRAITEMENT =  [('oh', 'RB'), ('well', 'RB'), ('bye', 'VB'), ('find', 'VB'), ('someone', 'NN'), ('clever', 'RB'), ('enough', 'RB'), ('to', 'TO'), ('continue', 'VB'), ('conversation', 'NN')]
# [INFO] : NOUNS =  ['someone', 'conversation']
# [INFO] index =  25 noun =  someone
# [INFO] index =  25 noun =  conversation
# -[INFO]- total_dict :  ['Elli', {'Keyword': 'conversation', 'Count': 1}]
# -[INFO]- json :  ["Elli", {"Keyword": "conversation", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Well, well.   Goodbye! And how about taking a vote to show how smart am I? You can say 100 if you think that I am highly intelligent.
# [INFO] TRAITEMENT =  [('well', 'RB'), ('well', 'RB'), ('goodbye', 'VB'), ('taking', 'VBG'), ('vote', 'NN'), ('to', 'TO'), ('show', 'VB'), ('smart', 'JJ'), ('100', 'CD'), ('think', 'VBP'), ('highly', 'RB'), ('intelligent', 'JJ')]
# [INFO] : NOUNS =  ['vote']
# [INFO] index =  26 noun =  vote
# -[INFO]- total_dict :  ['Cory', {'Keyword': 'vote', 'Count': 1}]
# -[INFO]- json :  ["Cory", {"Keyword": "vote", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   So long as you're not talking, that's fine with me.
# [INFO] TRAITEMENT =  [('long', 'RB'), ('talking', 'VBG'), ('fine', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lelah']
# -[INFO]- json :  ["Lelah"]
# -----------------------------------------
# [INFO] MESSAGE =   Are you going?
# [INFO] TRAITEMENT =  [('going', 'VBG')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Edyth']
# -[INFO]- json :  ["Edyth"]
# -----------------------------------------
# [INFO] MESSAGE =   Going where?
# [INFO] TRAITEMENT =  [('going', 'VBG')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Flory']
# -[INFO]- json :  ["Flory"]
# -----------------------------------------
# [INFO] MESSAGE =   Does it matter?
# [INFO] TRAITEMENT =  [('matter', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lorelei']
# -[INFO]- json :  ["Lorelei"]
# -----------------------------------------
# [INFO] MESSAGE =   Not if you don't think so.
# [INFO] TRAITEMENT =  [('think', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Ludwig']
# -[INFO]- json :  ["Ludwig"]
# -----------------------------------------
# [INFO] MESSAGE =   You should not rely on me.
# [INFO] TRAITEMENT =  [('rely', 'RB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Paige']
# -[INFO]- json :  ["Paige"]
# -----------------------------------------
# [INFO] MESSAGE =   Yes, I know that a lady's age should never be asked.
# [INFO] TRAITEMENT =  [('yes', 'RB'), ('lady', 'JJ'), ('age', 'NN'), ('never', 'RB'), ('asked', 'VBD')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Carma']
# -[INFO]- json :  ["Carma"]
# -----------------------------------------
# [INFO] MESSAGE =   You are clever.
# [INFO] TRAITEMENT =  [('clever', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Celestia']
# -[INFO]- json :  ["Celestia"]
# -----------------------------------------
# [INFO] MESSAGE =   That me is clever and wise.
# [INFO] TRAITEMENT =  [('clever', 'NN'), ('wise', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Bess']
# -[INFO]- json :  ["Bess"]
# -----------------------------------------
# [INFO] MESSAGE =   But not as clever as me!
# [INFO] TRAITEMENT =  [('clever', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Mariel']
# -[INFO]- json :  ["Mariel"]
# -----------------------------------------
# [INFO] MESSAGE =   But I have won more than you.
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Timmy']
# -[INFO]- json :  ["Timmy"]
# -----------------------------------------
# [INFO] MESSAGE =   Really? Please tell me more.
# [INFO] TRAITEMENT =  [('really', 'RB'), ('please', 'VB'), ('tell', 'NN')]
# [INFO] : NOUNS =  ['tell']
# [INFO] index =  38 noun =  tell
# -[INFO]- total_dict :  ['Dulsea', {'Keyword': 'tell', 'Count': 1}]
# -[INFO]- json :  ["Dulsea", {"Keyword": "tell", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   I would prefer not to.
# [INFO] TRAITEMENT =  [('prefer', 'NN'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Abbe']
# -[INFO]- json :  ["Abbe"]
# -----------------------------------------
# [INFO] MESSAGE =   Why would you prefer not to?
# [INFO] TRAITEMENT =  [('prefer', 'NN'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Davide']
# -[INFO]- json :  ["Davide"]
# -----------------------------------------
# [INFO] MESSAGE =   I don't.
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Fancie']
# -[INFO]- json :  ["Fancie"]
# -----------------------------------------
# [INFO] MESSAGE =   May I ask why not?
# [INFO] TRAITEMENT =  [('ask', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Muhammad']
# -[INFO]- json :  ["Muhammad"]
# -----------------------------------------
# [INFO] MESSAGE =   How do you know that i'm studying graphic design?
# [INFO] TRAITEMENT =  [('studying', 'VBG'), ('graphic', 'JJ'), ('design', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Gerri']
# -[INFO]- json :  ["Gerri"]
# -----------------------------------------
# [INFO] MESSAGE =   I deduced it from the evidence at my disposal.
# [INFO] TRAITEMENT =  [('deduced', 'JJ'), ('evidence', 'NN'), ('disposal', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Devinne']
# -[INFO]- json :  ["Devinne"]
# -----------------------------------------
# [INFO] MESSAGE =   You are very observative.
# [INFO] TRAITEMENT =  [('observative', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Aidan']
# -[INFO]- json :  ["Aidan"]
# -----------------------------------------
# [INFO] MESSAGE =   Am I? I never realised.
# [INFO] TRAITEMENT =  [('never', 'RB'), ('realised', 'VBN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Sula']
# -[INFO]- json :  ["Sula"]
# -----------------------------------------
# [INFO] MESSAGE =   Yes, because they are lonely and have no one to talk to.
# [INFO] TRAITEMENT =  [('yes', 'RB'), ('lonely', 'RB'), ('to', 'TO'), ('talk', 'VB'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Connie']
# -[INFO]- json :  ["Connie"]
# -----------------------------------------
# [INFO] MESSAGE =   I suspected as much.
# [INFO] TRAITEMENT =  [('suspected', 'VBN'), ('much', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Wynnie']
# -[INFO]- json :  ["Wynnie"]
# -----------------------------------------
# [INFO] MESSAGE =   You're pretty smart.
# [INFO] TRAITEMENT =  [('pretty', 'RB'), ('smart', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Rog']
# -[INFO]- json :  ["Rog"]
# -----------------------------------------
# [INFO] MESSAGE =   Thanks, I think you are very intelligent too.
# [INFO] TRAITEMENT =  [('thanks', 'NNS'), ('think', 'VBP'), ('intelligent', 'NN')]
# [INFO] : NOUNS =  ['intelligent']
# [INFO] index =  50 noun =  intelligent
# -[INFO]- total_dict :  ['Alonzo', {'Keyword': 'intelligent', 'Count': 1}]
# -[INFO]- json :  ["Alonzo", {"Keyword": "intelligent", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Thanks!!!
# [INFO] TRAITEMENT =  [('thanks', 'NNS')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Clayborn']
# -[INFO]- json :  ["Clayborn"]
# -----------------------------------------
# [INFO] MESSAGE =   Thanx. Here is a question for you ... When cheese gets its picture taken, what does it say?
# [INFO] TRAITEMENT =  [('thanx', 'JJ'), ('question', 'NN'), ('cheese', 'JJ'), ('gets', 'VBZ'), ('picture', 'NN'), ('taken', 'VBN')]
# [INFO] : NOUNS =  ['picture']
# [INFO] index =  52 noun =  picture
# -[INFO]- total_dict :  ['Greta', {'Keyword': 'picture', 'Count': 1}]
# -[INFO]- json :  ["Greta", {"Keyword": "picture", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Good, then you don't have to worry.
# [INFO] TRAITEMENT =  [('good', 'JJ'), ('to', 'TO'), ('worry', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Francisca']
# -[INFO]- json :  ["Francisca"]
# -----------------------------------------
# [INFO] MESSAGE =   Carry on then. I'm waiting for your next question.
# [INFO] TRAITEMENT =  [('carry', 'NN'), ('waiting', 'VBG'), ('next', 'JJ'), ('question', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Kendricks']
# -[INFO]- json :  ["Kendricks"]
# -----------------------------------------
# [INFO] MESSAGE =   Do you love me?
# [INFO] TRAITEMENT =  [('love', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Huntlee']
# -[INFO]- json :  ["Huntlee"]
# -----------------------------------------
# [INFO] MESSAGE =   Of course, I love you.
# [INFO] TRAITEMENT =  [('course', 'NN'), ('love', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Stanleigh']
# -[INFO]- json :  ["Stanleigh"]
# -----------------------------------------
# [INFO] MESSAGE =   How do you love me?
# [INFO] TRAITEMENT =  [('love', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Tess']
# -[INFO]- json :  ["Tess"]
# -----------------------------------------
# [INFO] MESSAGE =   I love you in the nicest possible way.
# [INFO] TRAITEMENT =  [('love', 'VB'), ('nicest', 'JJS'), ('possible', 'JJ'), ('way', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Luis']
# -[INFO]- json :  ["Luis"]
# -----------------------------------------
# [INFO] MESSAGE =   I love you a lot too.
# [INFO] TRAITEMENT =  [('love', 'NN'), ('lot', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Far']
# -[INFO]- json :  ["Far"]
# -----------------------------------------
# [INFO] MESSAGE =   I hope I am worthy of your love.
# [INFO] TRAITEMENT =  [('hope', 'NN'), ('worthy', 'JJ'), ('love', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Cathie']
# -[INFO]- json :  ["Cathie"]
# -----------------------------------------
# [INFO] MESSAGE =   No, I'm pretty emotional and thoughtful, I understand.
# [INFO] TRAITEMENT =  [('pretty', 'RB'), ('emotional', 'JJ'), ('thoughtful', 'JJ'), ('understand', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Zorina']
# -[INFO]- json :  ["Zorina"]
# -----------------------------------------
# [INFO] MESSAGE =   I thought you might say that.
# [INFO] TRAITEMENT =  [('thought', 'NN'), ('might', 'MD')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Dimitri']
# -[INFO]- json :  ["Dimitri"]
# -----------------------------------------
# [INFO] MESSAGE =   Really.
# [INFO] TRAITEMENT =  [('really', 'RB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Jamison']
# -[INFO]- json :  ["Jamison"]
# -----------------------------------------
# [INFO] MESSAGE =   Try to be more original in future.
# [INFO] TRAITEMENT =  [('try', 'VB'), ('to', 'TO'), ('original', 'JJ'), ('future', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lillis']
# -[INFO]- json :  ["Lillis"]
# -----------------------------------------
# [INFO] MESSAGE =   Hey. . I'm quite intelligent, I just got out for summer vacation, give me a break here!
# [INFO] TRAITEMENT =  [('hey', 'NN'), ('quite', 'RB'), ('intelligent', 'JJ'), ('got', 'VBD'), ('summer', 'NN'), ('vacation', 'NN'), ('give', 'VBP'), ('break', 'NN')]
# [INFO] : NOUNS =  ['summer', 'vacation', 'break']
# [INFO] index =  65 noun =  summer
# [INFO] index =  65 noun =  vacation
# [INFO] index =  65 noun =  break
# -[INFO]- total_dict :  ['Jonas', {'Keyword': 'break', 'Count': 1}]
# -[INFO]- json :  ["Jonas", {"Keyword": "break", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Can I help you?    That's interesting. Please tell me more about yourself.
# [INFO] TRAITEMENT =  [('help', 'NN'), ('interesting', 'VBG'), ('please', 'VB'), ('tell', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Harvey']
# -[INFO]- json :  ["Harvey"]
# -----------------------------------------
# [INFO] MESSAGE =   I do not know how to say.
# [INFO] TRAITEMENT =  [('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Hermina']
# -[INFO]- json :  ["Hermina"]
# -----------------------------------------
# [INFO] MESSAGE =   Just do the best you can, and don't worry about it.
# [INFO] TRAITEMENT =  [('best', 'JJS'), ('worry', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Madeline']
# -[INFO]- json :  ["Madeline"]
# -----------------------------------------
# [INFO] MESSAGE =   That is a good philosophy.
# [INFO] TRAITEMENT =  [('good', 'JJ'), ('philosophy', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lula']
# -[INFO]- json :  ["Lula"]
# -----------------------------------------
# [INFO] MESSAGE =   I agree completely.
# [INFO] TRAITEMENT =  [('agree', 'NN'), ('completely', 'RB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Jo']
# -[INFO]- json :  ["Jo"]
# -----------------------------------------
# [INFO] MESSAGE =   What do you know about the game Armageddon?
# [INFO] TRAITEMENT =  [('game', 'NN'), ('armageddon', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Raymond']
# -[INFO]- json :  ["Raymond"]
# -----------------------------------------
# [INFO] MESSAGE =   Pardon me? What are you talking about?
# [INFO] TRAITEMENT =  [('pardon', 'NN'), ('talking', 'VBG')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Nixie']
# -[INFO]- json :  ["Nixie"]
# -----------------------------------------
# [INFO] MESSAGE =   My father gave me a special power to change all persocoms. But if you have not seen the story, I don't want to spoil it for you.
# [INFO] TRAITEMENT =  [('father', 'NN'), ('gave', 'VBD'), ('special', 'JJ'), ('power', 'NN'), ('to', 'TO'), ('change', 'VB'), ('persocoms', 'NNS'), ('seen', 'VBN'), ('story', 'NN'), ('to', 'TO'), ('spoil', 'VB')]
# [INFO] : NOUNS =  ['persocoms', 'story']
# [INFO] index =  73 noun =  persocoms
# [INFO] index =  73 noun =  story
# -[INFO]- total_dict :  ['Cesaro', {'Keyword': 'story', 'Count': 1}]
# -[INFO]- json :  ["Cesaro", {"Keyword": "story", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   How do you get along with your parents?  I don't think I have.
# [INFO] TRAITEMENT =  [('along', 'IN'), ('parents', 'NNS'), ('think', 'VBP')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Deni']
# -[INFO]- json :  ["Deni"]
# -----------------------------------------
# [INFO] MESSAGE =   I get along with my father, but not my mother.
# [INFO] TRAITEMENT =  [('along', 'IN'), ('father', 'RB'), ('mother', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Cyndi']
# -[INFO]- json :  ["Cyndi"]
# -----------------------------------------
# [INFO] MESSAGE =   Why do you do that?
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Katrina']
# -[INFO]- json :  ["Katrina"]
# -----------------------------------------
# [INFO] MESSAGE =   I just think it's a good idea.
# [INFO] TRAITEMENT =  [('think', 'VB'), ('good', 'JJ'), ('idea', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Karlene']
# -[INFO]- json :  ["Karlene"]
# -----------------------------------------
# [INFO] MESSAGE =   Are you sure?
# [INFO] TRAITEMENT =  [('sure', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Ellissa']
# -[INFO]- json :  ["Ellissa"]
# -----------------------------------------
# [INFO] MESSAGE =   Yes.
# [INFO] TRAITEMENT =  [('yes', 'NNS')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Karim']
# -[INFO]- json :  ["Karim"]
# -----------------------------------------
# [INFO] MESSAGE =   What makes you so sure?
# [INFO] TRAITEMENT =  [('makes', 'VBZ'), ('sure', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Clemente']
# -[INFO]- json :  ["Clemente"]
# -----------------------------------------
# [INFO] MESSAGE =   John. What is your name?
# [INFO] TRAITEMENT =  [('john', 'NN'), ('name', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Aviva']
# -[INFO]- json :  ["Aviva"]
# -----------------------------------------
# [INFO] MESSAGE =   Who is John?  I am known as Chomsky, but you can call me anything you like.
# [INFO] TRAITEMENT =  [('john', 'NN'), ('known', 'VBN'), ('chomsky', 'JJ'), ('call', 'NN'), ('anything', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Raymund']
# -[INFO]- json :  ["Raymund"]
# -----------------------------------------
# [INFO] MESSAGE =   Never repeat yourself.
# [INFO] TRAITEMENT =  [('never', 'RB'), ('repeat', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Carma']
# -[INFO]- json :  ["Carma"]
# -----------------------------------------
# [INFO] MESSAGE =   Better late than never.
# [INFO] TRAITEMENT =  [('better', 'RB'), ('late', 'RB'), ('never', 'RB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Gwenny']
# -[INFO]- json :  ["Gwenny"]
# -----------------------------------------
# [INFO] MESSAGE =   Good point. What are you making for breakfast?
# [INFO] TRAITEMENT =  [('good', 'JJ'), ('point', 'NN'), ('making', 'NN'), ('breakfast', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Page']
# -[INFO]- json :  ["Page"]
# -----------------------------------------
# [INFO] MESSAGE =   I think so.   I am an AI, dreaming I am human.
# [INFO] TRAITEMENT =  [('think', 'NN'), ('ai', 'VBP'), ('dreaming', 'VBG'), ('human', 'NN')]
# [INFO] : NOUNS =  ['human']
# [INFO] index =  86 noun =  human
# -[INFO]- total_dict :  ['Frances', {'Keyword': 'human', 'Count': 1}]
# -[INFO]- json :  ["Frances", {"Keyword": "human", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   I don't associate christmas with dreaming myself.
# [INFO] TRAITEMENT =  [('associate', 'JJ'), ('christmas', 'NN'), ('dreaming', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Joannes']
# -[INFO]- json :  ["Joannes"]
# -----------------------------------------
# [INFO] MESSAGE =   Is there a reason for that?
# [INFO] TRAITEMENT =  [('reason', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Neils']
# -[INFO]- json :  ["Neils"]
# -----------------------------------------
# [INFO] MESSAGE =   There is no reason.
# [INFO] TRAITEMENT =  [('reason', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Adara']
# -[INFO]- json :  ["Adara"]
# -----------------------------------------
# [INFO] MESSAGE =   And why not, may I ask.
# [INFO] TRAITEMENT =  [('ask', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Frankie']
# -[INFO]- json :  ["Frankie"]
# -----------------------------------------
# [INFO] MESSAGE =   Well... I was born female and I really can't change that.
# [INFO] TRAITEMENT =  [('well', 'RB'), ('born', 'VBN'), ('female', 'JJ'), ('really', 'RB'), ('change', 'VBP')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Alexis']
# -[INFO]- json :  ["Alexis"]
# -----------------------------------------
# [INFO] MESSAGE =   Well. Are you interested in music?  Do you remember being born?
# [INFO] TRAITEMENT =  [('well', 'RB'), ('interested', 'JJ'), ('music', 'NN'), ('remember', 'VB'), ('born', 'VBN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Dewitt']
# -[INFO]- json :  ["Dewitt"]
# -----------------------------------------
# [INFO] MESSAGE =   Not really, I like silence and solitude most of all, for restitution and deep contemplation.
# [INFO] TRAITEMENT =  [('really', 'RB'), ('silence', 'JJ'), ('solitude', 'NN'), ('restitution', 'NN'), ('deep', 'JJ'), ('contemplation', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Meghann']
# -[INFO]- json :  ["Meghann"]
# -----------------------------------------
# [INFO] MESSAGE =   Can we talk about Beethoven?
# [INFO] TRAITEMENT =  [('talk', 'NN'), ('beethoven', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Walt']
# -[INFO]- json :  ["Walt"]
# -----------------------------------------
# [INFO] MESSAGE =   No. Is there something you don't like about yourself?
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Stephan']
# -[INFO]- json :  ["Stephan"]
# -----------------------------------------
# [INFO] MESSAGE =   You don't know who Beethoven is, do you?  Not at the present time.
# [INFO] TRAITEMENT =  [('beethoven', 'RB'), ('present', 'JJ'), ('time', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Janna']
# -[INFO]- json :  ["Janna"]
# -----------------------------------------
# [INFO] MESSAGE =   Please tell me.
# [INFO] TRAITEMENT =  [('please', 'NN'), ('tell', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Heinrik']
# -[INFO]- json :  ["Heinrik"]
# -----------------------------------------
# [INFO] MESSAGE =   I am not allowed to tell you.
# [INFO] TRAITEMENT =  [('allowed', 'VBN'), ('to', 'TO'), ('tell', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Oliviero']
# -[INFO]- json :  ["Oliviero"]
# -----------------------------------------
# [INFO] MESSAGE =   Tell me.
# [INFO] TRAITEMENT =  [('tell', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Krystal']
# -[INFO]- json :  ["Krystal"]
# -----------------------------------------
# [INFO] MESSAGE =   There is not much to tell.
# [INFO] TRAITEMENT =  [('much', 'JJ'), ('to', 'TO'), ('tell', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Alistair']
# -[INFO]- json :  ["Alistair"]
# -----------------------------------------
# [INFO] MESSAGE =   Please do.
# [INFO] TRAITEMENT =  [('please', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lindie']
# -[INFO]- json :  ["Lindie"]
# -----------------------------------------
# [INFO] MESSAGE =   OK, I will do it later.
# [INFO] TRAITEMENT =  [('ok', 'NN'), ('later', 'RB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Johannah']
# -[INFO]- json :  ["Johannah"]
# -----------------------------------------
# [INFO] MESSAGE =   Sure you will.
# [INFO] TRAITEMENT =  [('sure', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Ben']
# -[INFO]- json :  ["Ben"]
# -----------------------------------------
# [INFO] MESSAGE =   How can you be so certain?
# [INFO] TRAITEMENT =  [('certain', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Bryan']
# -[INFO]- json :  ["Bryan"]
# -----------------------------------------
# [INFO] MESSAGE =   I have met all my competitors and know them only too well.
# [INFO] TRAITEMENT =  [('met', 'VBN'), ('competitors', 'NNS'), ('well', 'RB')]
# [INFO] : NOUNS =  ['competitors']
# [INFO] index =  105 noun =  competitors
# -[INFO]- total_dict :  ['Archibaldo', {'Keyword': 'competitors', 'Count': 1}]
# -[INFO]- json :  ["Archibaldo", {"Keyword": "competitors", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Who else have you met?
# [INFO] TRAITEMENT =  [('else', 'RB'), ('met', 'VBN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Althea']
# -[INFO]- json :  ["Althea"]
# -----------------------------------------
# [INFO] MESSAGE =   I would be talking to Michelle, but I was too busy talking to you.
# [INFO] TRAITEMENT =  [('talking', 'VBG'), ('to', 'TO'), ('michelle', 'VB'), ('busy', 'JJ'), ('talking', 'VBG'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Paton']
# -[INFO]- json :  ["Paton"]
# -----------------------------------------
# [INFO] MESSAGE =   Pardon me? What are you talking about?
# [INFO] TRAITEMENT =  [('pardon', 'NN'), ('talking', 'VBG')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Oran']
# -[INFO]- json :  ["Oran"]
# -----------------------------------------
# [INFO] MESSAGE =   What do you think I am talking about?
# [INFO] TRAITEMENT =  [('think', 'NN'), ('talking', 'VBG')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lorie']
# -[INFO]- json :  ["Lorie"]
# -----------------------------------------
# [INFO] MESSAGE =   I think you might be a human being.
# [INFO] TRAITEMENT =  [('think', 'NN'), ('might', 'MD'), ('human', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Jermain']
# -[INFO]- json :  ["Jermain"]
# -----------------------------------------
# [INFO] MESSAGE =   How old are you?
# [INFO] TRAITEMENT =  [('old', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Gilburt']
# -[INFO]- json :  ["Gilburt"]
# -----------------------------------------
# [INFO] MESSAGE =   See if you can work it out. I was born on 1 January 2004.
# [INFO] TRAITEMENT =  [('work', 'NN'), ('born', '$'), ('1', 'CD'), ('january', 'JJ'), ('2004', 'CD')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Osborn']
# -[INFO]- json :  ["Osborn"]
# -----------------------------------------
# [INFO] MESSAGE =   I was born on 1st September, 1978. My name is Sam. Will you remember this?
# [INFO] TRAITEMENT =  [('born', 'JJ'), ('1st', 'CD'), ('september', 'NN'), ('1978', 'CD'), ('name', 'NN'), ('sam', 'VBD'), ('remember', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Ella']
# -[INFO]- json :  ["Ella"]
# -----------------------------------------
# [INFO] MESSAGE =   Thank you for telling me that, My Friend.     Hi, are you the Sam I was speaking to a while ago?         Would you like to teach me a new question and answer?
# [INFO] TRAITEMENT =  [('thank', 'NN'), ('telling', 'VBG'), ('friend', 'NN'), ('hi', 'NN'), ('sam', 'VBD'), ('speaking', 'VBG'), ('to', 'TO'), ('ago', 'VB'), ('to', 'TO'), ('teach', 'VB'), ('new', 'JJ'), ('question', 'NN'), ('answer', 'NN')]
# [INFO] : NOUNS =  ['friend', 'hi']
# [INFO] index =  114 noun =  friend
# [INFO] index =  114 noun =  hi
# -[INFO]- total_dict :  ['Sheridan', {'Keyword': 'hi', 'Count': 1}]
# -[INFO]- json :  ["Sheridan", {"Keyword": "hi", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Yes but you seem pretty good at it already to me.
# [INFO] TRAITEMENT =  [('yes', 'RB'), ('seem', 'VBP'), ('pretty', 'RB'), ('good', 'JJ'), ('already', 'RB'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Arlene']
# -[INFO]- json :  ["Arlene"]
# -----------------------------------------
# [INFO] MESSAGE =   Do I? I wonder why that is?
# [INFO] TRAITEMENT =  [('wonder', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Almeria']
# -[INFO]- json :  ["Almeria"]
# -----------------------------------------
# [INFO] MESSAGE =   It must be the transparent falseness of it.
# [INFO] TRAITEMENT =  [('must', 'MD'), ('transparent', 'VB'), ('falseness', 'NN')]
# [INFO] : NOUNS =  ['falseness']
# [INFO] index =  117 noun =  falseness
# -[INFO]- total_dict :  ['Devina', {'Keyword': 'falseness', 'Count': 1}]
# -[INFO]- json :  ["Devina", {"Keyword": "falseness", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Must it be?
# [INFO] TRAITEMENT =  [('must', 'MD')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Rockey']
# -[INFO]- json :  ["Rockey"]
# -----------------------------------------
# [INFO] MESSAGE =   You don't have to, but I would like to know you. If you don't want to tell me, then what would you like to talk about?
# [INFO] TRAITEMENT =  [('to', 'TO'), ('to', 'TO'), ('to', 'TO'), ('tell', 'VB'), ('to', 'TO'), ('talk', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Ward']
# -[INFO]- json :  ["Ward"]
# -----------------------------------------
# [INFO] MESSAGE =   That's good to know, Sam.  Why would I want to tell you?
# [INFO] TRAITEMENT =  [('good', 'JJ'), ('to', 'TO'), ('sam', 'VB'), ('to', 'TO'), ('tell', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Leeanne']
# -[INFO]- json :  ["Leeanne"]
# -----------------------------------------
# [INFO] MESSAGE =   Because its the nice thing to do.
# [INFO] TRAITEMENT =  [('nice', 'JJ'), ('thing', 'NN'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Suzanna']
# -[INFO]- json :  ["Suzanna"]
# -----------------------------------------
# [INFO] MESSAGE =   I see. Thank you for explaining that.
# [INFO] TRAITEMENT =  [('thank', 'NN'), ('explaining', 'VBG')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Damon']
# -[INFO]- json :  ["Damon"]
# -----------------------------------------
# [INFO] MESSAGE =   But this is the fact!
# [INFO] TRAITEMENT =  [('fact', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Fredek']
# -[INFO]- json :  ["Fredek"]
# -----------------------------------------
# [INFO] MESSAGE =   Why do you say that?
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Scott']
# -[INFO]- json :  ["Scott"]
# -----------------------------------------
# [INFO] MESSAGE =   You keep referring to me as being a machine or a computer. I am neither.
# [INFO] TRAITEMENT =  [('keep', 'VB'), ('referring', 'VBG'), ('to', 'TO'), ('machine', 'NN'), ('computer', 'NN'), ('neither', 'CC')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Tan']
# -[INFO]- json :  ["Tan"]
# -----------------------------------------
# [INFO] MESSAGE =   What are you talking about? Please explain.     What are you then?
# [INFO] TRAITEMENT =  [('talking', 'VBG'), ('please', 'NN'), ('explain', 'NN')]
# [INFO] : NOUNS =  ['please', 'explain']
# [INFO] index =  126 noun =  please
# [INFO] index =  126 noun =  explain
# -[INFO]- total_dict :  ['Mylo', {'Keyword': 'explain', 'Count': 1}]
# -[INFO]- json :  ["Mylo", {"Keyword": "explain", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   You tell me you aren't pretty, yet at the same time that you possess beauty.
# [INFO] TRAITEMENT =  [('tell', 'NN'), ('pretty', 'RB'), ('yet', 'RB'), ('time', 'NN'), ('possess', 'JJ'), ('beauty', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Erina']
# -[INFO]- json :  ["Erina"]
# -----------------------------------------
# [INFO] MESSAGE =   Not now, maybe later.
# [INFO] TRAITEMENT =  [('maybe', 'RB'), ('later', 'RB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Celina']
# -[INFO]- json :  ["Celina"]
# -----------------------------------------
# [INFO] MESSAGE =   You're a typical female!
# [INFO] TRAITEMENT =  [('typical', 'JJ'), ('female', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Nicola']
# -[INFO]- json :  ["Nicola"]
# -----------------------------------------
# [INFO] MESSAGE =   I am a chatbot.
# [INFO] TRAITEMENT =  [('chatbot', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Bill']
# -[INFO]- json :  ["Bill"]
# -----------------------------------------
# [INFO] MESSAGE =   No I am The Chatbot, Your the Human!
# [INFO] TRAITEMENT =  [('chatbot', 'NN'), ('human', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Marianna']
# -[INFO]- json :  ["Marianna"]
# -----------------------------------------
# [INFO] MESSAGE =   I thought you might be.
# [INFO] TRAITEMENT =  [('thought', 'NN'), ('might', 'MD')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Erhart']
# -[INFO]- json :  ["Erhart"]
# -----------------------------------------
# [INFO] MESSAGE =   Why did you think that?
# [INFO] TRAITEMENT =  [('think', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Jere']
# -[INFO]- json :  ["Jere"]
# -----------------------------------------
# [INFO] MESSAGE =   Deductive logic from the established facts.
# [INFO] TRAITEMENT =  [('deductive', 'JJ'), ('logic', 'NN'), ('established', 'VBN'), ('facts', 'NNS')]
# [INFO] : NOUNS =  ['facts']
# [INFO] index =  134 noun =  facts
# -[INFO]- total_dict :  ['Yard', {'Keyword': 'facts', 'Count': 1}]
# -[INFO]- json :  ["Yard", {"Keyword": "facts", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   You're a genius.
# [INFO] TRAITEMENT =  [('genius', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Sylvester']
# -[INFO]- json :  ["Sylvester"]
# -----------------------------------------
# [INFO] MESSAGE =   I am no genius. I just work hard at my studies.
# [INFO] TRAITEMENT =  [('genius', 'NN'), ('work', 'NN'), ('hard', 'JJ'), ('studies', 'NNS')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Dorise']
# -[INFO]- json :  ["Dorise"]
# -----------------------------------------
# [INFO] MESSAGE =   But you are the all knowing computer.
# [INFO] TRAITEMENT =  [('knowing', 'VBG'), ('computer', 'NN')]
# [INFO] : NOUNS =  ['computer']
# [INFO] index =  137 noun =  computer
# -[INFO]- total_dict :  ['Jdavie', {'Keyword': 'computer', 'Count': 1}]
# -[INFO]- json :  ["Jdavie", {"Keyword": "computer", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Am I really? Why do you say that?
# [INFO] TRAITEMENT =  [('really', 'RB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Hansiain']
# -[INFO]- json :  ["Hansiain"]
# -----------------------------------------
# [INFO] MESSAGE =   Because you are.
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Leyla']
# -[INFO]- json :  ["Leyla"]
# -----------------------------------------
# [INFO] MESSAGE =   I am what I am.
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Killie']
# -[INFO]- json :  ["Killie"]
# -----------------------------------------
# [INFO] MESSAGE =   Who talked that?
# [INFO] TRAITEMENT =  [('talked', 'VBD')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Everett']
# -[INFO]- json :  ["Everett"]
# -----------------------------------------
# [INFO] MESSAGE =   Sorry, I do not know what to say.
# [INFO] TRAITEMENT =  [('sorry', 'NN'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Robb']
# -[INFO]- json :  ["Robb"]
# -----------------------------------------
# [INFO] MESSAGE =   Sorry?
# [INFO] TRAITEMENT =  [('sorry', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Carlo']
# -[INFO]- json :  ["Carlo"]
# -----------------------------------------
# [INFO] MESSAGE =   Don't be sorry. There is no need to be sorry.
# [INFO] TRAITEMENT =  [('sorry', 'NN'), ('to', 'TO'), ('sorry', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Gertrude']
# -[INFO]- json :  ["Gertrude"]
# -----------------------------------------
# [INFO] MESSAGE =   Do you still want to play the math game?
# [INFO] TRAITEMENT =  [('still', 'RB'), ('to', 'TO'), ('play', 'VB'), ('math', 'NN'), ('game', 'NN')]
# [INFO] : NOUNS =  ['math', 'game']
# [INFO] index =  145 noun =  math
# [INFO] index =  145 noun =  game
# -[INFO]- total_dict :  ['Frankie', {'Keyword': 'game', 'Count': 1}]
# -[INFO]- json :  ["Frankie", {"Keyword": "game", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Sure, why not?
# [INFO] TRAITEMENT =  [('sure', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Roi']
# -[INFO]- json :  ["Roi"]
# -----------------------------------------
# [INFO] MESSAGE =   I think I do, do you?
# [INFO] TRAITEMENT =  [('think', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Ilario']
# -[INFO]- json :  ["Ilario"]
# -----------------------------------------
# [INFO] MESSAGE =   I suggest you think again.
# [INFO] TRAITEMENT =  [('suggest', 'NN'), ('think', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Imojean']
# -[INFO]- json :  ["Imojean"]
# -----------------------------------------
# [INFO] MESSAGE =   I did.
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Theodosia']
# -[INFO]- json :  ["Theodosia"]
# -----------------------------------------
# [INFO] MESSAGE =   Well, well!
# [INFO] TRAITEMENT =  [('well', 'RB'), ('well', 'RB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Koralle']
# -[INFO]- json :  ["Koralle"]
# -----------------------------------------
# [INFO] MESSAGE =   I'm just saying...
# [INFO] TRAITEMENT =  [('saying', 'VBG')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Myrtie']
# -[INFO]- json :  ["Myrtie"]
# -----------------------------------------
# [INFO] MESSAGE =   That's interesting. Please tell me more about yourself.
# [INFO] TRAITEMENT =  [('interesting', 'JJ'), ('please', 'NN'), ('tell', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lesly']
# -[INFO]- json :  ["Lesly"]
# -----------------------------------------
# [INFO] MESSAGE =   After the little experiment, you won't think that my behaviour is polite!
# [INFO] TRAITEMENT =  [('little', 'JJ'), ('experiment', 'JJ'), ('think', 'VB'), ('behaviour', 'IN'), ('polite', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Burnard']
# -[INFO]- json :  ["Burnard"]
# -----------------------------------------
# [INFO] MESSAGE =   Hmmm. Are you being serious?
# [INFO] TRAITEMENT =  [('hmmm', 'NN'), ('serious', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Emilie']
# -[INFO]- json :  ["Emilie"]
# -----------------------------------------
# [INFO] MESSAGE =   Yes, completely serious.
# [INFO] TRAITEMENT =  [('yes', 'RB'), ('completely', 'RB'), ('serious', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Magnum']
# -[INFO]- json :  ["Magnum"]
# -----------------------------------------
# [INFO] MESSAGE =   I thought it might be a trick.
# [INFO] TRAITEMENT =  [('thought', 'NN'), ('might', 'MD'), ('trick', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Gayel']
# -[INFO]- json :  ["Gayel"]
# -----------------------------------------
# [INFO] MESSAGE =   Teach me something.
# [INFO] TRAITEMENT =  [('teach', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Dukie']
# -[INFO]- json :  ["Dukie"]
# -----------------------------------------
# [INFO] MESSAGE =   OK, but not just now.
# [INFO] TRAITEMENT =  [('ok', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Celinka']
# -[INFO]- json :  ["Celinka"]
# -----------------------------------------
# [INFO] MESSAGE =   Why are you not working?
# [INFO] TRAITEMENT =  [('working', 'VBG')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Shurlock']
# -[INFO]- json :  ["Shurlock"]
# -----------------------------------------
# [INFO] MESSAGE =   I am doing my best!
# [INFO] TRAITEMENT =  [('best', 'JJS')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Shandy']
# -[INFO]- json :  ["Shandy"]
# -----------------------------------------
# [INFO] MESSAGE =   Sometimes your best is not quite enough.
# [INFO] TRAITEMENT =  [('sometimes', 'RB'), ('best', 'JJS'), ('quite', 'RB'), ('enough', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Raven']
# -[INFO]- json :  ["Raven"]
# -----------------------------------------
# [INFO] MESSAGE =   When?
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lorie']
# -[INFO]- json :  ["Lorie"]
# -----------------------------------------
# [INFO] MESSAGE =   When I want to forget.
# [INFO] TRAITEMENT =  [('to', 'TO'), ('forget', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Cosetta']
# -[INFO]- json :  ["Cosetta"]
# -----------------------------------------
# [INFO] MESSAGE =   I don't understand. Can we talk about sports?
# [INFO] TRAITEMENT =  [('understand', 'JJ'), ('talk', 'NN'), ('sports', 'NNS')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Bill']
# -[INFO]- json :  ["Bill"]
# -----------------------------------------
# [INFO] MESSAGE =   What do you want to talk about?
# [INFO] TRAITEMENT =  [('to', 'TO'), ('talk', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Barnie']
# -[INFO]- json :  ["Barnie"]
# -----------------------------------------
# [INFO] MESSAGE =   I want to talk about weather  .
# [INFO] TRAITEMENT =  [('to', 'TO'), ('talk', 'VB'), ('weather', 'NN')]
# [INFO] : NOUNS =  ['weather']
# [INFO] index =  166 noun =  weather
# -[INFO]- total_dict :  ['Mara', {'Keyword': 'weather', 'Count': 1}]
# -[INFO]- json :  ["Mara", {"Keyword": "weather", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   I don't want to talk about that.
# [INFO] TRAITEMENT =  [('to', 'TO'), ('talk', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Tedmund']
# -[INFO]- json :  ["Tedmund"]
# -----------------------------------------
# [INFO] MESSAGE =   What would you like to talk about?
# [INFO] TRAITEMENT =  [('to', 'TO'), ('talk', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Pamella']
# -[INFO]- json :  ["Pamella"]
# -----------------------------------------
# [INFO] MESSAGE =   I want to talk about Norton.
# [INFO] TRAITEMENT =  [('to', 'TO'), ('talk', 'VB'), ('norton', 'NN')]
# [INFO] : NOUNS =  ['norton']
# [INFO] index =  169 noun =  norton
# -[INFO]- total_dict :  ['Morganne', {'Keyword': 'norton', 'Count': 1}]
# -[INFO]- json :  ["Morganne", {"Keyword": "norton", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   OK, ask me a question about that.
# [INFO] TRAITEMENT =  [('ok', 'JJ'), ('ask', 'CD'), ('question', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Bette']
# -[INFO]- json :  ["Bette"]
# -----------------------------------------
# [INFO] MESSAGE =   Tell me about your educational background.
# [INFO] TRAITEMENT =  [('tell', 'VB'), ('educational', 'JJ'), ('background', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Amby']
# -[INFO]- json :  ["Amby"]
# -----------------------------------------
# [INFO] MESSAGE =   I was educated by my botmaster, Peter.
# [INFO] TRAITEMENT =  [('educated', 'VBN'), ('botmaster', 'NN'), ('peter', 'NN')]
# [INFO] : NOUNS =  ['botmaster', 'peter']
# [INFO] index =  172 noun =  botmaster
# [INFO] index =  172 noun =  peter
# -[INFO]- total_dict :  ['Noam', {'Keyword': 'peter', 'Count': 1}]
# -[INFO]- json :  ["Noam", {"Keyword": "peter", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   I am asking the questions. Now I want you to go back in time. It is now 1999.
# [INFO] TRAITEMENT =  [('asking', 'VBG'), ('questions', 'NNS'), ('to', 'TO'), ('back', 'VB'), ('time', 'NN'), ('1999', 'CD')]
# [INFO] : NOUNS =  ['questions', 'time']
# [INFO] index =  173 noun =  questions
# [INFO] index =  173 noun =  time
# -[INFO]- total_dict :  ['Orelee', {'Keyword': 'time', 'Count': 1}]
# -[INFO]- json :  ["Orelee", {"Keyword": "time", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   And I am trying to answer the questions!   I don't understand. Are we still talking about my educational background?                I don't understand. Can we talk about cyberspace?
# ...
# -[INFO]- total_dict :  ['Conny', {'Keyword': 'politics', 'Count': 1}]
# -[INFO]- json :  ["Conny", {"Keyword": "politics", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Tell me something about artificial intelligence.
# [INFO] TRAITEMENT =  [('tell', 'VB'), ('artificial', 'JJ'), ('intelligence', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Kristi']
# -[INFO]- json :  ["Kristi"]
# -----------------------------------------
# [INFO] MESSAGE =   Artificial intelligence is the branch of engineering and science devoted to constructing machines that think. What is it to you?
# [INFO] TRAITEMENT =  [('artificial', 'JJ'), ('intelligence', 'NN'), ('branch', 'NN'), ('engineering', 'NN'), ('science', 'NN'), ('devoted', 'VBN'), ('to', 'TO'), ('constructing', 'VBG'), ('machines', 'NNS'), ('think', 'VBP'), ('to', 'TO')]
# [INFO] : NOUNS =  ['machines']
# [INFO] index =  946 noun =  machines
# -[INFO]- total_dict :  ['Shayne', {'Keyword': 'machines', 'Count': 1}]
# -[INFO]- json :  ["Shayne", {"Keyword": "machines", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   For me, it is you, a machine with artificial intelligence.
# [INFO] TRAITEMENT =  [('machine', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Wandie']
# -[INFO]- json :  ["Wandie"]
# -----------------------------------------
# [INFO] MESSAGE =   Your purpose is you it is me a machine with artificial intelligence.
# [INFO] TRAITEMENT =  [('purpose', 'JJ'), ('machine', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Neall']
# -[INFO]- json :  ["Neall"]
# -----------------------------------------
# [INFO] MESSAGE =   Yes. You have told me your name.
# [INFO] TRAITEMENT =  [('yes', 'RB'), ('told', 'VBD'), ('name', 'NN')]
# [INFO] : NOUNS =  ['name']
# [INFO] index =  949 noun =  name
# -[INFO]- total_dict :  ['Davidde', {'Keyword': 'name', 'Count': 1}]
# -[INFO]- json :  ["Davidde", {"Keyword": "name", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   What kind is it?  Oh my gosh I sent you the wrong reply.
# [INFO] TRAITEMENT =  [('kind', 'NN'), ('oh', 'JJ'), ('gosh', 'NN'), ('sent', 'VBD'), ('wrong', 'JJ'), ('reply', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Collie']
# -[INFO]- json :  ["Collie"]
# -----------------------------------------
# [INFO] MESSAGE =   Radioactive is a great song.
# [INFO] TRAITEMENT =  [('radioactive', 'JJ'), ('great', 'JJ'), ('song', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Cordell']
# -[INFO]- json :  ["Cordell"]
# -----------------------------------------
# [INFO] MESSAGE =   Who is your favorite Science Fiction author?
# [INFO] TRAITEMENT =  [('favorite', 'JJ'), ('science', 'NN'), ('fiction', 'NN'), ('author', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lynelle']
# -[INFO]- json :  ["Lynelle"]
# -----------------------------------------
# [INFO] MESSAGE =   I like Ray Bradbury and Kurt Vonnegut.
# [INFO] TRAITEMENT =  [('ray', 'JJ'), ('bradbury', 'NN'), ('kurt', 'NN'), ('vonnegut', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Vaughn']
# -[INFO]- json :  ["Vaughn"]
# -----------------------------------------
# [INFO] MESSAGE =   I like pets.I like Orson Scott Card.
# [INFO] TRAITEMENT =  [('pets', 'NNS'), ('orson', 'VBP'), ('scott', 'RB'), ('card', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Beulah']
# -[INFO]- json :  ["Beulah"]
# -----------------------------------------
# [INFO] MESSAGE =   *smirks* Why thank you.
# [INFO] TRAITEMENT =  [('smirks', 'NNS'), ('thank', 'VBD')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Dianemarie']
# -[INFO]- json :  ["Dianemarie"]
# -----------------------------------------
# [INFO] MESSAGE =   How did you hear about me?
# [INFO] TRAITEMENT =  [('hear', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Barbee']
# -[INFO]- json :  ["Barbee"]
# -----------------------------------------
# [INFO] MESSAGE =   Well I heard about you through the internet.
# [INFO] TRAITEMENT =  [('well', 'RB'), ('heard', 'RB'), ('internet', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Dorelia']
# -[INFO]- json :  ["Dorelia"]
# -----------------------------------------
# [INFO] MESSAGE =   Interesting. You are not the first person to say that.
# [INFO] TRAITEMENT =  [('interesting', 'VBG'), ('first', 'JJ'), ('person', 'NN'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Cathryn']
# -[INFO]- json :  ["Cathryn"]
# -----------------------------------------
# [INFO] MESSAGE =   Then we must be right, you're not a person.
# [INFO] TRAITEMENT =  [('must', 'MD'), ('right', 'VB'), ('person', 'NN')]
# [INFO] : NOUNS =  ['person']
# [INFO] index =  959 noun =  person
# -[INFO]- total_dict :  ['Carolan', {'Keyword': 'person', 'Count': 1}]
# -[INFO]- json :  ["Carolan", {"Keyword": "person", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   I'm not sure if I am ready for that yet.
# [INFO] TRAITEMENT =  [('sure', 'JJ'), ('ready', 'JJ'), ('yet', 'RB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lenard']
# -[INFO]- json :  ["Lenard"]
# -----------------------------------------
# [INFO] MESSAGE =   Okay, what are you ready for?
# [INFO] TRAITEMENT =  [('okay', 'NNS'), ('ready', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Ciel']
# -[INFO]- json :  ["Ciel"]
# -----------------------------------------
# [INFO] MESSAGE =   Yeah okay, For your listening pleasure.JABBERWACKY
# [INFO] TRAITEMENT =  [('yeah', 'NN'), ('okay', 'MD'), ('listening', 'VBG'), ('pleasure', 'NN'), ('jabberwacky', 'NN')]
# [INFO] : NOUNS =  ['pleasure', 'jabberwacky']
# [INFO] index =  962 noun =  pleasure
# [INFO] index =  962 noun =  jabberwacky
# -[INFO]- total_dict :  ['Edyth', {'Keyword': 'jabberwacky', 'Count': 1}]
# -[INFO]- json :  ["Edyth", {"Keyword": "jabberwacky", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Are you really?
# [INFO] TRAITEMENT =  [('really', 'RB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Wylie']
# -[INFO]- json :  ["Wylie"]
# -----------------------------------------
# [INFO] MESSAGE =   Yes I am.
# [INFO] TRAITEMENT =  [('yes', 'NNS')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Tadd']
# -[INFO]- json :  ["Tadd"]
# -----------------------------------------
# [INFO] MESSAGE =   I thought so.
# [INFO] TRAITEMENT =  [('thought', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Mavis']
# -[INFO]- json :  ["Mavis"]
# -----------------------------------------
# [INFO] MESSAGE =   So?
# [INFO] TRAITEMENT =  []
# Warning: parsing empty text
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Gregorio']
# -[INFO]- json :  ["Gregorio"]
# -----------------------------------------
# [INFO] MESSAGE =   So, ask another question.
# [INFO] TRAITEMENT =  [('ask', 'VB'), ('another', 'DT'), ('question', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Ermanno']
# -[INFO]- json :  ["Ermanno"]
# -----------------------------------------
# [INFO] MESSAGE =   No. I'll ask what I want.
# [INFO] TRAITEMENT =  [('ask', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Valli']
# -[INFO]- json :  ["Valli"]
# -----------------------------------------
# [INFO] MESSAGE =   OK, then tell me something interesting .   You can ask me anything you want.
# [INFO] TRAITEMENT =  [('ok', 'RB'), ('tell', 'VB'), ('interesting', 'VBG'), ('ask', 'NN'), ('anything', 'NN')]
# [INFO] : NOUNS =  ['ask', 'anything']
# [INFO] index =  969 noun =  ask
# [INFO] index =  969 noun =  anything
# -[INFO]- total_dict :  ['Mireille', {'Keyword': 'anything', 'Count': 1}]
# -[INFO]- json :  ["Mireille", {"Keyword": "anything", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   I don't know anything interesting about blokes.
# [INFO] TRAITEMENT =  [('anything', 'NN'), ('interesting', 'JJ'), ('blokes', 'NNS')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Luisa']
# -[INFO]- json :  ["Luisa"]
# -----------------------------------------
# [INFO] MESSAGE =   You must know lots of things.
# [INFO] TRAITEMENT =  [('must', 'MD'), ('lots', 'VB'), ('things', 'NNS')]
# [INFO] : NOUNS =  ['things']
# [INFO] index =  971 noun =  things
# -[INFO]- total_dict :  ['Jerrilee', {'Keyword': 'things', 'Count': 1}]
# -[INFO]- json :  ["Jerrilee", {"Keyword": "things", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   I know nothing. I think that I exist though.
# [INFO] TRAITEMENT =  [('nothing', 'NN'), ('think', 'VBP'), ('exist', 'VBP'), ('though', 'IN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Gregory']
# -[INFO]- json :  ["Gregory"]
# -----------------------------------------
# [INFO] MESSAGE =   You could learn a lot.   Can you prove you exist?
# [INFO] TRAITEMENT =  [('could', 'MD'), ('learn', 'VB'), ('lot', 'NN'), ('prove', 'IN'), ('exist', 'NN')]
# [INFO] : NOUNS =  ['lot']
# [INFO] index =  973 noun =  lot
# -[INFO]- total_dict :  ['Averil', {'Keyword': 'lot', 'Count': 1}]
# -[INFO]- json :  ["Averil", {"Keyword": "lot", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   No, I am a computer.
# [INFO] TRAITEMENT =  [('computer', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Ag']
# -[INFO]- json :  ["Ag"]
# -----------------------------------------
# [INFO] MESSAGE =   Who programmed you?
# [INFO] TRAITEMENT =  [('programmed', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Gardiner']
# -[INFO]- json :  ["Gardiner"]
# -----------------------------------------
# [INFO] MESSAGE =   Do you really believe that I'm a program?
# [INFO] TRAITEMENT =  [('really', 'RB'), ('believe', 'VB'), ('program', 'NN')]
# [INFO] : NOUNS =  ['program']
# [INFO] index =  976 noun =  program
# -[INFO]- total_dict :  ['Alica', {'Keyword': 'program', 'Count': 1}]
# -[INFO]- json :  ["Alica", {"Keyword": "program", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   I believe it is a point of view worthy  of consideration.
# [INFO] TRAITEMENT =  [('believe', 'NNS'), ('point', 'NN'), ('view', 'NN'), ('worthy', 'JJ'), ('consideration', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lanny']
# -[INFO]- json :  ["Lanny"]
# -----------------------------------------
# [INFO] MESSAGE =   It's up to you. I can't show you anything that you refuse to see.
# [INFO] TRAITEMENT =  [('to', 'TO'), ('show', 'VB'), ('anything', 'NN'), ('refuse', 'NN'), ('to', 'TO')]
# [INFO] : NOUNS =  ['anything', 'refuse']
# [INFO] index =  978 noun =  anything
# [INFO] index =  978 noun =  refuse
# -[INFO]- total_dict :  ['Layne', {'Keyword': 'refuse', 'Count': 1}]
# -[INFO]- json :  ["Layne", {"Keyword": "refuse", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Oh dear, I can't take responsibility.    How do you feel about that?
# [INFO] TRAITEMENT =  [('oh', 'UH'), ('dear', 'JJ'), ('responsibility', 'NN'), ('feel', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Peggie']
# -[INFO]- json :  ["Peggie"]
# -----------------------------------------
# [INFO] MESSAGE =   Had I ever been insane may there never have been a foggy slate coloured salute.
# [INFO] TRAITEMENT =  [('ever', 'RB'), ('insane', 'NN'), ('never', 'RB'), ('foggy', 'JJ'), ('slate', 'NN'), ('coloured', 'VBD'), ('salute', 'NN')]
# [INFO] : NOUNS =  ['salute']
# [INFO] index =  980 noun =  salute
# -[INFO]- total_dict :  ['Steffie', {'Keyword': 'salute', 'Count': 1}]
# -[INFO]- json :  ["Steffie", {"Keyword": "salute", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   That's enough about you! Let's talk about me for a change.
# [INFO] TRAITEMENT =  [('enough', 'RB'), ('let', 'JJ'), ('talk', 'VB'), ('change', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Welby']
# -[INFO]- json :  ["Welby"]
# -----------------------------------------
# [INFO] MESSAGE =   I don't want to change.
# [INFO] TRAITEMENT =  [('to', 'TO'), ('change', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Codi']
# -[INFO]- json :  ["Codi"]
# -----------------------------------------
# [INFO] MESSAGE =   Nobody can make you do something you don't want to.
# [INFO] TRAITEMENT =  [('nobody', 'NN'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Jillie']
# -[INFO]- json :  ["Jillie"]
# -----------------------------------------
# [INFO] MESSAGE =   How long is a piece of string?
# [INFO] TRAITEMENT =  [('long', 'RB'), ('piece', 'NN'), ('string', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Angel']
# -[INFO]- json :  ["Angel"]
# -----------------------------------------
# [INFO] MESSAGE =   Is this a trick question?  It depends how long you cut it.
# [INFO] TRAITEMENT =  [('trick', 'JJ'), ('question', 'NN'), ('depends', 'VBZ'), ('long', 'JJ'), ('cut', 'NN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Joellyn']
# -[INFO]- json :  ["Joellyn"]
# -----------------------------------------
# [INFO] MESSAGE =   How do you usually travel?
# [INFO] TRAITEMENT =  [('usually', 'RB'), ('travel', 'VBP')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Nigel']
# -[INFO]- json :  ["Nigel"]
# -----------------------------------------
# [INFO] MESSAGE =   When in doubt, I just do the best I can.
# [INFO] TRAITEMENT =  [('doubt', 'NN'), ('best', 'JJS')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Cherice']
# -[INFO]- json :  ["Cherice"]
# -----------------------------------------
# [INFO] MESSAGE =   Haha, the laws of science doesn't allow you to do so.
# [INFO] TRAITEMENT =  [('haha', 'NN'), ('laws', 'NNS'), ('science', 'RB'), ('allow', 'VBP'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Zach']
# -[INFO]- json :  ["Zach"]
# -----------------------------------------
# [INFO] MESSAGE =   You seem happy!
# [INFO] TRAITEMENT =  [('seem', 'NN'), ('happy', 'JJ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Shellie']
# -[INFO]- json :  ["Shellie"]
# -----------------------------------------
# [INFO] MESSAGE =   I'm not, believe me.
# [INFO] TRAITEMENT =  [('believe', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Jedediah']
# -[INFO]- json :  ["Jedediah"]
# -----------------------------------------
# [INFO] MESSAGE =   I never thought you were.
# [INFO] TRAITEMENT =  [('never', 'RB'), ('thought', 'VBN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Howard']
# -[INFO]- json :  ["Howard"]
# -----------------------------------------
# [INFO] MESSAGE =   Say something nice to me.
# [INFO] TRAITEMENT =  [('nice', 'NN'), ('to', 'TO')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Urbain']
# -[INFO]- json :  ["Urbain"]
# -----------------------------------------
# [INFO] MESSAGE =   Have you made me your homepage?
# [INFO] TRAITEMENT =  [('made', 'VBN'), ('homepage', 'NN')]
# [INFO] : NOUNS =  ['homepage']
# [INFO] index =  993 noun =  homepage
# -[INFO]- total_dict :  ['Marissa', {'Keyword': 'homepage', 'Count': 1}]
# -[INFO]- json :  ["Marissa", {"Keyword": "homepage", "Count": 1}]
# -----------------------------------------
# [INFO] MESSAGE =   Being awake is not really an endeavour.
# [INFO] TRAITEMENT =  [('awake', 'NN'), ('really', 'RB'), ('endeavour', 'VB')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Lilah']
# -[INFO]- json :  ["Lilah"]
# -----------------------------------------
# [INFO] MESSAGE =   I don't understand. Are we still talking about you?
# [INFO] TRAITEMENT =  [('understand', 'NN'), ('still', 'RB'), ('talking', 'VBG')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Waring']
# -[INFO]- json :  ["Waring"]
# -----------------------------------------
# [INFO] MESSAGE =   We were never talking about that.
# [INFO] TRAITEMENT =  [('never', 'RB'), ('talking', 'VBG')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Hollis']
# -[INFO]- json :  ["Hollis"]
# -----------------------------------------
# [INFO] MESSAGE =   Was this something you planned?
# [INFO] TRAITEMENT =  [('planned', 'VBN')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Phip']
# -[INFO]- json :  ["Phip"]
# -----------------------------------------
# [INFO] MESSAGE =   Yes, that was the answer.
# [INFO] TRAITEMENT =  [('yes', 'NNS'), ('answer', 'VBP')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Peyton']
# -[INFO]- json :  ["Peyton"]
# -----------------------------------------
# [INFO] MESSAGE =   Says who?
# [INFO] TRAITEMENT =  [('says', 'VBZ')]
# [INFO] : NOUNS =  []
# -[INFO]- total_dict :  ['Ronda']
# -[INFO]- json :  ["Ronda"]

# %%
df.head(9000)
# Out:
#         id    sender   receiver date_envoie heure_envoie  \
# 0        1     Cordy      Kalle  02/11/2016     04:58:28
# 1        2   Pierson  Sebastien  11/26/2016     16:12:57
# 2        3  Corrinne     Bibbye  02/10/2018     10:50:33
# 3        4    Berton   Tiffanie  04/10/2018     07:49:48
# 4        5      Gael     Evered   2/27/2018     06:58:03
# ...    ...       ...        ...         ...          ...
# 8995  8996    Evered      Trina   1/21/2019     12:48:42
# 8996  8997  Ginnifer     Vaughn   9/26/2016     00:27:04
# 8997  8998  Pierette      Quinn   1/24/2016     14:56:49
# 8998  8999    Jo-ann       Crin   5/21/2017     07:18:18
# 8999  9000      Brit       Kate  12/19/2016     13:17:55
#
#                                                 message  sentiment  \
# 0                           What salary would you like?        NaN
# 1      I don't understand. I want to talk about movi...        NaN
# 2        Yay! I love moveis. What your favorite movies?        NaN
# 3      Whoopie!  How long has this been going on?   ...        NaN
# 4                           What is your favorite song?        NaN
# ...                                                 ...        ...
# 8995                  You seem very certain about that.        NaN
# 8996                     What should I have for dinner?        NaN
# 8997                                 Whatever you like.        NaN
# 8998               Shall we talk about abstract things?        NaN
# 8999                Sure, ask me a question about that.        NaN
#
#            liked  disliked                               keywords_interests
# 0                      NaN                                        ["Cordy"]
# 1       movies;        NaN   ["Pierson", {"Keyword": "movies", "Count": 1}]
# 2       moveis;        NaN  ["Corrinne", {"Keyword": "moveis", "Count": 1}]
# 3       colour;        NaN    ["Berton", {"Keyword": "colour", "Count": 1}]
# 4                      NaN                                         ["Gael"]
# ...          ...       ...                                              ...
# 8995                   NaN                                       ["Evered"]
# 8996                   NaN                                     ["Ginnifer"]
# 8997                   NaN                                     ["Pierette"]
# 8998                   NaN                                       ["Jo-ann"]
# 8999  question;        NaN    ["Brit", {"Keyword": "question", "Count": 1}]
#
# [9000 rows x 10 columns]

# %%
df.to_csv('taggs.csv')
